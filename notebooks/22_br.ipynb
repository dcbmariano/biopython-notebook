# %% [markdown]
# **Source of the materials**: Biopython cookbook (adapted)
# <font color='red'>Status: Draft</font>

# %% [markdown]
# **Fonte dos materiais** : livro de receitas Biopython (adaptado)
#
#  &lt;font color = &#39;red&#39;&gt; Status: Rascunho &lt;/font&gt;

# %% [markdown]
# Where to go from here – contributing to Biopython
# =================================================
#
# Bug Reports + Feature Requests
# ------------------------------
#
# Getting feedback on the Biopython modules is very important to us.
# Open-source projects like this benefit greatly from feedback,
# bug-reports (and patches!) from a wide variety of contributors.
#
# The main forums for discussing feature requests and potential bugs are
# the [Biopython mailing lists](http://biopython.org/wiki/Mailing_lists):
#
# -   – An unmoderated list for discussion of anything to do
#     with Biopython.
#
# -   – A more development oriented list that is mainly used by developers
#     (but anyone is free to contribute!).
#
# Additionally, if you think you’ve found a new bug, you can submit it to
# our issue tracker at <https://github.com/biopython/biopython/issues>
# (this has replaced the older tracker hosted at
# <http://redmine.open-bio.org/projects/biopython>). This way, it won’t
# get buried in anyone’s Inbox and forgotten about.
#
# Mailing lists and helping newcomers
# -----------------------------------
#
# We encourage all our uses to sign up to the main Biopython mailing list.
# Once you’ve got the hang of an area of Biopython, we’d encourage you to
# help answer questions from beginners. After all, you were a beginner
# once.
#
# Contributing Documentation
# --------------------------
#
# We’re happy to take feedback or contributions - either via a bug-report
# or on the Mailing List. While reading this tutorial, perhaps you noticed
# some topics you were interested in which were missing, or not clearly
# explained. There is also Biopython’s built in documentation (the
# docstrings, these are also
# [online](http://biopython.org/DIST/docs/api)), where again, you may be
# able to help fill in any blanks.
#
# Contributing cookbook examples
# ------------------------------
#
# As explained in Chapter \[chapter:cookbook\], Biopython now has a wiki
# collection of user contributed “cookbook” examples,
# <http://biopython.org/wiki/Category:Cookbook> – maybe you can add to
# this?
#
# Maintaining a distribution for a platform {#sec:maintain_dist}
# -----------------------------------------
#
# We currently provide source code archives (suitable for any OS, if you
# have the right build tools installed), and Windows Installers which are
# just click and run. This covers all the major operating systems.
#
# Most major Linux distributions have volunteers who take these source
# code releases, and compile them into packages for Linux users to easily
# install (taking care of dependencies etc). This is really great and we
# are of course very grateful. If you would like to contribute to this
# work, please find out more about how your Linux distribution handles
# this.
#
# Below are some tips for certain platforms to maybe get people started
# with helping out:
#
# Windows
#
# :   – Windows products typically have a nice graphical installer that
#     installs all of the essential components in the right place. We use
#     Distutils to create a installer of this type fairly easily.
#
#     You must first make sure you have a C compiler on your Windows
#     computer, and that you can compile and install things (this is the
#     hard bit - see the Biopython installation instructions for info on
#     how to do this).
#
#     Once you are setup with a C compiler, making the installer just
#     requires doing:

# %% [markdown]
# Para onde ir a partir daqui - contribuindo para Biopython
#
#  =======================================================
#
#  Relatórios de bug + solicitações de recursos
#
#  Obter feedback sobre os módulos Biopython é muito importante para nós.
#
#  Projetos de código aberto como este se beneficiam muito do feedback,
#
#  relatórios de bugs (e patches!) de uma ampla variedade de contribuidores.
#
#  Os principais fóruns para discutir solicitações de recursos e possíveis bugs são
#
#  as [listas de discussão Biopython](http://biopython.org/wiki/Mailing_lists) :
# -  - Uma lista não moderada para discussão de qualquer coisa a fazer com Biopython.
# -  - Uma lista mais orientada para o desenvolvimento, usada principalmente por desenvolvedores (mas qualquer pessoa é livre para contribuir!).
#
#  Além disso, se você acha que encontrou um novo bug, pode enviá-lo para
#
#  nosso rastreador de problemas em [https://github.com/biopython/biopython/issues](https://github.com/biopython/biopython/issues)
#
#  (substituiu o rastreador antigo hospedado em
#
#  [http://redmine.open-bio.org/projects/biopython](http://redmine.open-bio.org/projects/biopython) ). Assim não
#
#  ser enterrado na caixa de entrada de qualquer pessoa e esquecido.
#
#  Listas de mala direta e ajuda aos recém-chegados
#
#  Nós encorajamos todos os nossos usuários a se inscreverem na lista de discussão principal do Biopython.
#
#  Assim que você pegar o jeito de uma área de Biopython, nós o encorajamos a
#
#  ajudar a responder a perguntas de iniciantes. Afinal, você era um iniciante
#
#  uma vez.
#
#  Contribuição de documentação
#
#  Ficamos felizes em receber comentários ou contribuições - por meio de um relatório de bug
#
#  ou na lista de mala direta. Ao ler este tutorial, talvez você tenha notado
#
#  alguns tópicos de seu interesse que estavam faltando ou não estavam claramente
#
#  explicou. Há também a documentação embutida do Biopython (o
#
#  docstrings, estes também são
#
#  [online](http://biopython.org/DIST/docs/api) ), onde, novamente, você pode estar
#
#  capaz de ajudar a preencher quaisquer lacunas.
#
#  Contribuindo com exemplos de livros de receitas
#
#  Conforme explicado no Capítulo [capítulo: livro de receitas], Biopython agora tem um wiki
#
#  coleção de exemplos de "livros de receitas" contribuídos pelo usuário,
#
#  [http://biopython.org/wiki/Category:Cookbook](http://biopython.org/wiki/Category:Cookbook) - talvez você possa adicionar a
#
#  esta?
#
#  Manter uma distribuição para uma plataforma {#sec: keep_dist}
#
#  Atualmente, fornecemos arquivos de código-fonte (adequados para qualquer sistema operacional, se você
#
#  ter as ferramentas de compilação corretas instaladas) e Windows Installers que são
#
#  basta clicar e correr. Isso cobre todos os principais sistemas operacionais.
#
#  A maioria das principais distribuições de Linux tem voluntários que pegam essas fontes
#
#  lançamentos de código e compilá-los em pacotes para usuários Linux para facilmente
#
#  instalar (cuidar das dependências, etc.). Isso é realmente ótimo e nós
#
#  são, claro, muito gratos. Se você gostaria de contribuir para isso
#
#  trabalho, por favor, descubra mais sobre como sua distribuição Linux lida
#
#  esta.
#
#  Abaixo estão algumas dicas para certas plataformas para talvez ajudar as pessoas a começar
#
#  com a ajuda:
#
#  janelas
#
#  : - Os produtos Windows normalmente têm um bom instalador gráfico que

# %% [markdown]
# ```
# python setup.py bdist_wininst
#
# ```

# %% [markdown]
# ```
#
# python setup.py bdist_wininst
#
# ```

# %% [markdown]
#     Now you’ve got a Windows installer. Congrats! At the moment we have
#     no trouble shipping installers built on 32 bit windows. If anyone
#     would like to look into supporting 64 bit Windows that would
#     be great.
#
# RPMs
#
# :   – RPMs are pretty popular package systems on some Linux platforms.
#     There is lots of documentation on RPMs available at
#     <http://www.rpm.org> to help you get started with them. To create an
#     RPM for your platform is really easy. You just need to be able to
#     build the package from source (having a C compiler that works is
#     thus essential) – see the Biopython installation instructions for
#     more info on this.
#
#     To make the RPM, you just need to do:

# %% [markdown]
# ```
# Now you&#39;ve got a Windows installer. Congrats! At the moment we have no trouble shipping installers built on 32 bit windows. If anyone would like to look into supporting 64 bit Windows that would be great.
# ```
#
#  RPMs
#
#  : - RPMs são sistemas de pacotes bastante populares em algumas plataformas Linux.

# %% [markdown]
# ```
# python setup.py bdist_rpm
#
# ```

# %% [markdown]
# ```
#
# python setup.py bdist_rpm
#
# ```
